# %% [markdown]
# # 01 - Single Izhikevich Neuron
#
# ## Objetivo
# Implementar y visualizar una neurona Izhikevich individual.
#
# ## Parte del proyecto
# Fase 1: neurona individual y dinámica spiking básica.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

import numpy as np
import matplotlib.pyplot as plt

from src.config import DEFAULT_IZHIKEVICH_PARAMS, SIMULATION_TIME_MS, TIME_STEP_MS
from src.neuron_models import simulate_single_neuron
from src.inputs import constant_input
from src.visualization import plot_voltage_trace

# %% [markdown]
# ## TODO - Implementación
# - Implementar `izhikevich_step` en `src/neuron_models.py`.
# - Implementar `simulate_single_neuron`.
# - Generar una corriente constante inicial para probar la neurona.

# %%
# TODO: crear vector de tiempo, input constante y correr la simulación.
# time = np.arange(0, SIMULATION_TIME_MS, TIME_STEP_MS)
# current = constant_input(time, amplitude=10.0)
# voltage, recovery, spikes = simulate_single_neuron(current, DEFAULT_IZHIKEVICH_PARAMS, TIME_STEP_MS)

# %% [markdown]
# ## TODO - Gráficos
# - Graficar el potencial de membrana.
# - Marcar tiempos de spike.
# - Revisar si el patrón corresponde a una neurona regular-spiking.

# %%
# TODO: usar plot_voltage_trace(time, voltage, spike_times=spikes).

# %% [markdown]
# ## TODO - Interpretación
# - Describir umbral, frecuencia aproximada y adaptación.
# - Registrar parámetros usados y comportamiento observado.
