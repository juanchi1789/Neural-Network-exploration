# %% [markdown]
# # 07 - Visual Muscle Demo
#
# ## Objetivo
# Crear una visualización simple de un músculo o brazo 2D que se contrae según la fuerza simulada.
#
# ## Parte del proyecto
# Fase 7: transformar la salida del modelo en una demostración visual interpretable.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

import numpy as np
import matplotlib.pyplot as plt

from src.visualization import animate_muscle_contraction
from src.config import ANIMATIONS_DIR

# %% [markdown]
# ## TODO - Implementación
# - Diseñar una animación 2D simple del músculo o brazo.
# - Mapear fuerza normalizada a contracción visual.
# - Exportar la animación a `outputs/animations/` si corresponde.

# %%
# TODO: cargar o generar una señal de fuerza y crear animación.

# %% [markdown]
# ## TODO - Gráficos
# - Mostrar frames clave de la contracción.
# - Comparar fuerza simulada con estado visual.

# %%
# TODO: visualizar frames o reproducir animación en el notebook.

# %% [markdown]
# ## TODO - Interpretación
# - Evaluar si la visualización comunica correctamente la relación spikes-fuerza-movimiento.
# - Documentar limitaciones visuales y posibles mejoras.
