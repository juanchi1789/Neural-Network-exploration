# %% [markdown]
# # 02 - Neuron Input Experiments
#
# ## Objetivo
# Probar respuestas ante corriente constante, pulso, rampa, ruido y señal sinusoidal.
#
# ## Parte del proyecto
# Fase 2: exploración sistemática de estímulos.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

import numpy as np
import matplotlib.pyplot as plt

from src.config import DEFAULT_IZHIKEVICH_PARAMS, SIMULATION_TIME_MS, TIME_STEP_MS
from src.inputs import constant_input, pulse_input, ramp_input, sinusoidal_input, noisy_input
from src.neuron_models import simulate_single_neuron

# %% [markdown]
# ## TODO - Implementación
# - Implementar generadores de input en `src/inputs.py`.
# - Ejecutar la misma neurona con distintos estímulos.
# - Comparar cambios en firing rate y patrón temporal.

# %%
# TODO: construir inputs constante, pulso, rampa, sinusoidal y ruidoso.
# TODO: simular la neurona para cada input y guardar resultados comparables.

# %% [markdown]
# ## TODO - Gráficos
# - Graficar input y voltaje en paneles alineados.
# - Comparar raster o marcas de spikes por condición.

# %%
# TODO: crear figuras comparativas para las distintas corrientes.

# %% [markdown]
# ## TODO - Interpretación
# - Identificar qué tipos de input generan spikes sostenidos, transitorios o irregulares.
# - Relacionar los resultados con el objetivo motor del proyecto.
