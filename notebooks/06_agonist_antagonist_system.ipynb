# %% [markdown]
# # 06 - Agonist and Antagonist System
#
# ## Objetivo
# Simular dos pools motores para músculos agonista y antagonista.
#
# ## Parte del proyecto
# Fase 6: integrar inhibición recíproca y fuerza neta.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

import numpy as np
import matplotlib.pyplot as plt

from src.inhibition import reciprocal_inhibition
from src.muscle import compute_net_force
from src.metrics import co_contraction_index

# %% [markdown]
# ## TODO - Implementación
# - Crear comandos motores para agonista y antagonista.
# - Aplicar inhibición recíproca simplificada.
# - Convertir ambas salidas a fuerza y calcular fuerza neta.

# %%
# TODO: simular dos pools y calcular fuerza neta o proxy de movimiento.

# %% [markdown]
# ## TODO - Gráficos
# - Graficar fuerzas agonista, antagonista y neta.
# - Mostrar índice de co-contracción.

# %%
# TODO: visualizar fuerzas y balance agonista-antagonista.

# %% [markdown]
# ## TODO - Interpretación
# - Analizar balance entre activación e inhibición.
# - Explicar el significado del proxy de movimiento.
