# %% [markdown]
# # 05 - Recurrent Inhibition: Renshaw-like Feedback
#
# ## Objetivo
# Agregar inhibición recurrente tipo Renshaw.
#
# ## Parte del proyecto
# Fase 5: regular la salida motora con feedback inhibitorio.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

import numpy as np
import matplotlib.pyplot as plt

from src.inhibition import renshaw_feedback, apply_inhibitory_current
from src.network import simulate_motor_pool

# %% [markdown]
# ## TODO - Implementación
# - Implementar feedback recurrente simplificado.
# - Comparar actividad del pool con y sin inhibición.
# - Explorar ganancia y delay del feedback.

# %%
# TODO: aplicar inhibición recurrente sobre un comando motor de prueba.

# %% [markdown]
# ## TODO - Gráficos
# - Graficar input original, feedback inhibitorio y output regulado.
# - Comparar raster plots con y sin feedback.

# %%
# TODO: visualizar regulación de actividad motora.

# %% [markdown]
# ## TODO - Interpretación
# - Discutir cómo el feedback limita o estabiliza la actividad.
# - Aclarar diferencias frente a un circuito Renshaw biológico completo.
